# %%
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
classes = ['T-shirt/Top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.imshow(train_images[i], cmap= plt.cm.binary)
  plt.xlabel(classes[train_labels[i]])
plt.show()

# %%
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1)
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1)

# %% [markdown]
# ### **CNN with 1 Convolutional Layer**

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape = (28, 28, 1)),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
        ])

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics= ['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs=10)
test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 1.2690 - accuracy: 0.8234
# Epoch 2/10
# 1875/1875 [==============================] - 37s 19ms/step - loss: 0.3166 - accuracy: 0.8866
# Epoch 3/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2754 - accuracy: 0.8992
# Epoch 4/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2544 - accuracy: 0.9072
# Epoch 5/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2367 - accuracy: 0.9140
# Epoch 6/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.2209 - accuracy: 0.9191
# Epoch 7/10
# 1793/1875 [===========================>..] - ETA: 1s - loss: 0.2042 - accuracy: 0.9251

# %%
print("Test- accuracy: ", test_accuracy)
# Out:
# Tes accuracy:  0.8962000012397766

# %%
model.optimizer.lr = 0.0001

# %%
model.fit(train_images, train_labels, epochs=10)
test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.1013 - accuracy: 0.9624
# Epoch 2/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.0868 - accuracy: 0.9679
# Epoch 3/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0798 - accuracy: 0.9711
# Epoch 4/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0746 - accuracy: 0.9730
# Epoch 5/10
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0698 - accuracy: 0.9751
# Epoch 6/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.0656 - accuracy: 0.9768
# Epoch 7/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.0620 - accuracy: 0.9782
# Epoch 8/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.0585 - accuracy: 0.9796
# Epoch 9/10
# 1875/1875 [==============================] - 36s 19ms/step - loss: 0.0550 - accuracy: 0.9806
# Epoch 10/10
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.0520 - accuracy: 0.9821
# 313/313 - 2s - loss: 0.5122 - accuracy: 0.9040

# %%
print("Test accuracy: ", test_accuracy)
# Out:
# Tes accuracy:  0.9039999842643738

# %%
model2 = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape = (28, 28, 1)),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Dropout(0.2),

        tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Dropout(0.2),

        
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
        ])

# %% [markdown]
# ## CNN with 2 Convolutional Layer

# %%
model2.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics= ['accuracy'])

# %%
model2.fit(train_images, train_labels, epochs=10)
test_loss, test_accuracy = model2.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 59s 31ms/step - loss: 0.6199 - accuracy: 0.8120
# Epoch 2/10
# 1875/1875 [==============================] - 59s 31ms/step - loss: 0.3619 - accuracy: 0.8663
# Epoch 3/10
# 1875/1875 [==============================] - 59s 31ms/step - loss: 0.3302 - accuracy: 0.8782
# Epoch 4/10
# 1875/1875 [==============================] - 58s 31ms/step - loss: 0.3095 - accuracy: 0.8842
# Epoch 5/10
# 1875/1875 [==============================] - 57s 30ms/step - loss: 0.2952 - accuracy: 0.8892
# Epoch 6/10
# 1875/1875 [==============================] - 58s 31ms/step - loss: 0.2816 - accuracy: 0.8952
# Epoch 7/10
# 1875/1875 [==============================] - 57s 31ms/step - loss: 0.2732 - accuracy: 0.8967
# Epoch 8/10
# 1875/1875 [==============================] - 57s 30ms/step - loss: 0.2669 - accuracy: 0.9012
# Epoch 9/10
# 1875/1875 [==============================] - 59s 32ms/step - loss: 0.2606 - accuracy: 0.9023
# Epoch 10/10
# 1875/1875 [==============================] - 59s 31ms/step - loss: 0.2511 - accuracy: 0.9048
# 313/313 - 3s - loss: 0.2932 - accuracy: 0.8977

# %%
print("Test accuracy: ", test_accuracy)
# Out:
# Test accuracy:  0.8977000117301941

# %%
model2.optimizer.lr = 0.0001

# %%
model2.fit(train_images, train_labels, epochs=10)
test_loss, test_accuracy = model2.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 60s 32ms/step - loss: 0.2045 - accuracy: 0.9218
# Epoch 2/10
# 1875/1875 [==============================] - 59s 32ms/step - loss: 0.1892 - accuracy: 0.9268
# Epoch 3/10
# 1875/1875 [==============================] - 61s 32ms/step - loss: 0.1867 - accuracy: 0.9279
# Epoch 4/10
# 1875/1875 [==============================] - 60s 32ms/step - loss: 0.1807 - accuracy: 0.9306
# Epoch 5/10
# 1875/1875 [==============================] - 60s 32ms/step - loss: 0.1734 - accuracy: 0.9325
# Epoch 6/10
# 1875/1875 [==============================] - 59s 32ms/step - loss: 0.1728 - accuracy: 0.9330
# Epoch 7/10
# 1875/1875 [==============================] - 60s 32ms/step - loss: 0.1685 - accuracy: 0.9349
# Epoch 8/10
# 1875/1875 [==============================] - 61s 33ms/step - loss: 0.1662 - accuracy: 0.9349
# Epoch 9/10
# 1875/1875 [==============================] - 61s 32ms/step - loss: 0.1638 - accuracy: 0.9366
# Epoch 10/10
# 1875/1875 [==============================] - 61s 33ms/step - loss: 0.1641 - accuracy: 0.9372
# 313/313 - 2s - loss: 0.2578 - accuracy: 0.9112

# %%
print("Test accuracy: ", test_accuracy)
# Out:
# Test accuracy:  0.9111999869346619

# %%
model2.fit(train_images, train_labels, epochs=15)
test_loss, test_accuracy = model2.evaluate(test_images, test_labels, verbose=2)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 58s 31ms/step - loss: 0.2065 - accuracy: 0.9236
# Epoch 2/15
# 1875/1875 [==============================] - 58s 31ms/step - loss: 0.2064 - accuracy: 0.9226
# Epoch 3/15
# 1875/1875 [==============================] - 58s 31ms/step - loss: 0.2112 - accuracy: 0.9223
# Epoch 4/15
# 1875/1875 [==============================] - 58s 31ms/step - loss: 0.2105 - accuracy: 0.9223
# Epoch 5/15
# 1875/1875 [==============================] - 61s 33ms/step - loss: 0.2039 - accuracy: 0.9247
# Epoch 6/15
# 1875/1875 [==============================] - 62s 33ms/step - loss: 0.2047 - accuracy: 0.9251
# Epoch 7/15
# 1875/1875 [==============================] - 60s 32ms/step - loss: 0.2113 - accuracy: 0.9226
# Epoch 8/15
# 1875/1875 [==============================] - 60s 32ms/step - loss: 0.2079 - accuracy: 0.9255
# Epoch 9/15
# 1875/1875 [==============================] - 63s 34ms/step - loss: 0.2033 - accuracy: 0.9258
# Epoch 10/15
# 1875/1875 [==============================] - 61s 32ms/step - loss: 0.2035 - accuracy: 0.9252
# Epoch 11/15
# 1875/1875 [==============================] - 59s 32ms/step - loss: 0.2035 - accuracy: 0.9266
# Epoch 12/15
# 1875/1875 [==============================] - 63s 33ms/step - loss: 0.2025 - accuracy: 0.9255
# Epoch 13/15
# 1875/1875 [==============================] - 59s 31ms/step - loss: 0.2049 - accuracy: 0.9241
# Epoch 14/15
# 1875/1875 [==============================] - 59s 31ms/step - loss: 0.2033 - accuracy: 0.9264
# Epoch 15/15
# 1875/1875 [==============================] - 58s 31ms/step - loss: 0.2035 - accuracy: 0.9267
# 313/313 - 2s - loss: 0.3372 - accuracy: 0.8933

# %%
print("Test accuracy: ", test_accuracy)
# Out:
# Test accuracy:  0.8932999968528748
